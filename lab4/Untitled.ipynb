# %%
import pandas as pd
import numpy as np

# Models
from statsmodels.stats.outliers_influence import variance_inflation_factor
import sklearn.metrics as metrics
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Plot
import matplotlib.pyplot as plt
import seaborn as sns

# Settings
from varname import nameof

np.set_printoptions(precision=3)
pd.set_option('precision', 3)

sns.set()

# %%
test = pd.read_csv("test.csv")
test
# Out:
#       Index  Gender  Senior Married Dependents  Tenure Phone  \
# 0         0    Male       0      No         No      58   Yes
# 1         1  Female       0     Yes        Yes      26   Yes
# 2         2  Female       0      No         No      26   Yes
# 3         3    Male       0      No         No      12   Yes
# 4         4  Female       0      No         No       1   Yes
# ...     ...     ...     ...     ...        ...     ...   ...
# 2390   2390    Male       0      No         No      62    No
# 2391   2391  Female       0     Yes         No       2   Yes
# 2392   2392  Female       0     Yes        Yes      23   Yes
# 2393   2393    Male       1     Yes         No      53   Yes
# 2394   2394  Female       0      No         No      30   Yes
#
#         MultiplePhones     Internet             Security               Backup  \
# 0                   No  Fiber optic                  Yes                  Yes
# 1                   No  Fiber optic                   No                   No
# 2                   No  Fiber optic                  Yes                   No
# 3                  Yes          DSL                  Yes                  Yes
# 4                  Yes  Fiber optic                   No                   No
# ...                ...          ...                  ...                  ...
# 2390  No phone service          DSL                  Yes                  Yes
# 2391                No           No  No internet service  No internet service
# 2392               Yes  Fiber optic                   No                   No
# 2393               Yes  Fiber optic                   No                  Yes
# 2394               Yes  Fiber optic                  Yes                   No
#
#                 Insurance              Support                   TV  \
# 0                      No                   No                  Yes
# 1                      No                   No                  Yes
# 2                     Yes                  Yes                   No
# 3                      No                  Yes                   No
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 2390                  Yes                  Yes                   No
# 2391  No internet service  No internet service  No internet service
# 2392                   No                   No                  Yes
# 2393                   No                   No                  Yes
# 2394                   No                  Yes                  Yes
#
#                    Movies        Contract EBilling              PaymentMethod  \
# 0                     Yes        One year       No  Bank transfer (automatic)
# 1                     Yes  Month-to-month      Yes           Electronic check
# 2                      No        One year      Yes    Credit card (automatic)
# 3                      No  Month-to-month      Yes           Electronic check
# 4                      No  Month-to-month      Yes               Mailed check
# ...                   ...             ...      ...                        ...
# 2390                   No        Two year      Yes  Bank transfer (automatic)
# 2391  No internet service  Month-to-month       No  Bank transfer (automatic)
# 2392                   No  Month-to-month      Yes           Electronic check
# 2393                  Yes  Month-to-month      Yes           Electronic check
# 2394                  Yes  Month-to-month       No  Bank transfer (automatic)
#
#       MonthlyCharges TotalCharges
# 0              99.15      5720.95
# 1              90.80       2361.8
# 2              87.15       2274.1
# 3              67.25        832.3
# 4              75.05        75.05
# ...              ...          ...
# 2390           43.70       2618.3
# 2391           20.10        43.15
# 2392           83.75      1849.95
# 2393          101.90       5549.4
# 2394          106.40       3211.9
#
# [2395 rows x 20 columns]

# %%
train = pd.read_csv("test.csv")
train
# Out:
#       Index  Gender  Senior Married Dependents  Tenure Phone  \
# 0         0    Male       0      No         No      58   Yes
# 1         1  Female       0     Yes        Yes      26   Yes
# 2         2  Female       0      No         No      26   Yes
# 3         3    Male       0      No         No      12   Yes
# 4         4  Female       0      No         No       1   Yes
# ...     ...     ...     ...     ...        ...     ...   ...
# 2390   2390    Male       0      No         No      62    No
# 2391   2391  Female       0     Yes         No       2   Yes
# 2392   2392  Female       0     Yes        Yes      23   Yes
# 2393   2393    Male       1     Yes         No      53   Yes
# 2394   2394  Female       0      No         No      30   Yes
#
#         MultiplePhones     Internet             Security               Backup  \
# 0                   No  Fiber optic                  Yes                  Yes
# 1                   No  Fiber optic                   No                   No
# 2                   No  Fiber optic                  Yes                   No
# 3                  Yes          DSL                  Yes                  Yes
# 4                  Yes  Fiber optic                   No                   No
# ...                ...          ...                  ...                  ...
# 2390  No phone service          DSL                  Yes                  Yes
# 2391                No           No  No internet service  No internet service
# 2392               Yes  Fiber optic                   No                   No
# 2393               Yes  Fiber optic                   No                  Yes
# 2394               Yes  Fiber optic                  Yes                   No
#
#                 Insurance              Support                   TV  \
# 0                      No                   No                  Yes
# 1                      No                   No                  Yes
# 2                     Yes                  Yes                   No
# 3                      No                  Yes                   No
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 2390                  Yes                  Yes                   No
# 2391  No internet service  No internet service  No internet service
# 2392                   No                   No                  Yes
# 2393                   No                   No                  Yes
# 2394                   No                  Yes                  Yes
#
#                    Movies        Contract EBilling              PaymentMethod  \
# 0                     Yes        One year       No  Bank transfer (automatic)
# 1                     Yes  Month-to-month      Yes           Electronic check
# 2                      No        One year      Yes    Credit card (automatic)
# 3                      No  Month-to-month      Yes           Electronic check
# 4                      No  Month-to-month      Yes               Mailed check
# ...                   ...             ...      ...                        ...
# 2390                   No        Two year      Yes  Bank transfer (automatic)
# 2391  No internet service  Month-to-month       No  Bank transfer (automatic)
# 2392                   No  Month-to-month      Yes           Electronic check
# 2393                  Yes  Month-to-month      Yes           Electronic check
# 2394                  Yes  Month-to-month       No  Bank transfer (automatic)
#
#       MonthlyCharges TotalCharges
# 0              99.15      5720.95
# 1              90.80       2361.8
# 2              87.15       2274.1
# 3              67.25        832.3
# 4              75.05        75.05
# ...              ...          ...
# 2390           43.70       2618.3
# 2391           20.10        43.15
# 2392           83.75      1849.95
# 2393          101.90       5549.4
# 2394          106.40       3211.9
#
# [2395 rows x 20 columns]
